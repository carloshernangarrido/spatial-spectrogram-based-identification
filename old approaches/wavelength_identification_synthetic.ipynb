# %%
import pandas as pd
from os import path
import matplotlib.pyplot as plt
from scipy import signal, interpolate
from scipy.spatial.distance import cdist
import numpy as np
import folium
from sklearn.preprocessing import MinMaxScaler

# %%
source_path = r"C:\Users\joses\Mi unidad\TRABAJO\49_profile_estimation\TRABAJO\car_models\synthetic_dataset\four_ramps_cwl"

win_len = 500

speed_stopped_th = .01 # m/s

# %% [markdown]
# # Data Extraction

# %%
subtract_g = False
fs_acc = 100 # sps

# Dataset 1
i_ini, i_fin = 10, 235 # s
acc_orig_df_1 = pd.read_csv(path.join(source_path, "0/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
if subtract_g:
    acc_orig_df_1['z'] = acc_orig_df_1['z'] - 9.81
loc_orig_df_1 = pd.read_csv(path.join(source_path, "0/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_1 = loc_orig_df_1.loc[loc_orig_df_1['speed'] > speed_stopped_th].reset_index()

# Dataset 2
i_ini, i_fin = 10, 175 # s
acc_orig_df_2 = pd.read_csv(path.join(source_path, "1/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
if subtract_g:
    acc_orig_df_2['z'] = acc_orig_df_2['z'] - 9.81
loc_orig_df_2 = pd.read_csv(path.join(source_path, "1/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_2 = loc_orig_df_2.loc[loc_orig_df_2['speed'] > speed_stopped_th].reset_index()

plt.plot(loc_orig_df_1['longitude'], loc_orig_df_1['latitude'], label='dataset_1')
plt.plot(loc_orig_df_2['longitude'], loc_orig_df_2['latitude'], label='dataset_2')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.legend()
plt.show()

# %% [markdown]
# ## Raw Visualization

# %%
fig, ax = plt.subplots(1, 2, sharey='row')
ax[0].plot(acc_orig_df_1['seconds_elapsed'], acc_orig_df_1['z'])
ax[0].plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'])
ax[1].plot(acc_orig_df_2['seconds_elapsed'], acc_orig_df_2['z'])
ax[1].plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'])

# %% [markdown]
# # Feature extraction

# %% [markdown]
# Global spectrum

# %%
f = np.linspace(0, fs_acc/2, win_len//2 + 1)
global_spectrum_1 = signal.welch(acc_orig_df_1['z'].values, fs=fs_acc, nperseg=win_len, noverlap=win_len//2)[1]
global_spectrum_2 = signal.welch(acc_orig_df_2['z'].values, fs=fs_acc, nperseg=win_len, noverlap=win_len//2)[1]
fig, ax = plt.subplots(1, 1, sharex='col')
ax.plot(f, global_spectrum_1, label='global spectrum 1')
ax.plot(f, global_spectrum_2, label='global spectrum 2')
ax.set_title('Global Spectrums')
ax.set_xlabel('Frequency [Hz]')
# Out:
# Text(0.5, 0, 'Frequency [Hz]')

# %% [markdown]
# ## Spectrograms

# %%
# plot expectrograms of acc_z
# Expectrograms

def plot_spectrogram(spectrogram_, ax=None, tlim=None, flim=None, title=None, spatial=False, x_index=False):
    f, t, Sxx = spectrogram_
    if x_index:
        t = np.arange(len(t))
    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 3))
    else:
        fig = ax.figure
    im = ax.pcolormesh(t, f, Sxx, shading=None, cmap='hot')
    ax.set_ylabel('Frequency [Hz]' if not spatial else 'Spatial frequency [1/m]')
    ax.set_xlabel('Time [s]' if not x_index else 'Sample index')
    fig.colorbar(im, ax=ax)
    if tlim is not None:
        ax.set_xlim(tlim)
    if flim is not None:
        ax.set_ylim(flim)
    ax.set_title(title if title else 'Spectrogram')

    return ax

def get_spectrogram(acc_orig_df_n, fs, win_len):
    # Compute the spectrogram
    f, t, Sxx = signal.spectrogram(acc_orig_df_n['z'], fs=fs, nperseg=win_len)
    # Correct the time vector using seconds_elapsed
    t = np.interp(t, np.linspace(t[0], t[-1], len(acc_orig_df_n['seconds_elapsed'])), acc_orig_df_n['seconds_elapsed'])
    return (f, t, Sxx)

spectrogram_1 = get_spectrogram(acc_orig_df_1, fs=fs_acc, win_len=win_len)
spectrogram_2 = get_spectrogram(acc_orig_df_2, fs=fs_acc, win_len=win_len)

tmax = 250
tlim = (-20, tmax)
ax = plot_spectrogram(spectrogram_1, tlim=tlim, title='Expectrogram of acc_z dataset 1')
ax_ = plot_spectrogram(spectrogram_2, tlim=tlim, title='Expectrogram of acc_z dataset 2')

# %% [markdown]
# Normalized spectrograms

# %%
spectrogram_1_norm = (spectrogram_1[0], spectrogram_1[1], spectrogram_1[2]/global_spectrum_1.reshape(-1, 1))
spectrogram_2_norm = (spectrogram_2[0], spectrogram_2[1], spectrogram_2[2]/global_spectrum_2.reshape(-1, 1))

ax = plot_spectrogram(spectrogram_1_norm, tlim=(0, tmax), title='Expectrogram of acc_z dataset 1')
ax_ = plot_spectrogram(spectrogram_2_norm, tlim=(0, tmax), title='Expectrogram of acc_z dataset 2')

# %% [markdown]
# ## Spatial Spectrograms
# $f = \text{temporal frequency}$
#
# $f_s = \text{spatial frequency}$
#
# $v = \text{vehicle speed}$
#
# $f = v f_s$

# %%
from typing import Union
min_wl = 0.2  # meter
max_wl = 10.0  # meter

def get_spatial_spectrogram(spectrogram: tuple, tv: np.ndarray, min_wl: float, max_wl: float) -> tuple:
    spatial_frequencies = np.linspace(1/max_wl, 1/min_wl, len(spectrogram[0]))
    f, t, Sxx = spectrogram
    Sxx_spatial = 0 * Sxx
    for i, t_ in enumerate(t):
        Sxx_spatial[:, i] = np.interp(np.interp(t_, tv[:,0], tv[:,1])*spatial_frequencies, f, Sxx[:, i])
    return spatial_frequencies, t, Sxx_spatial

spatial_spectrogram_1_norm = get_spatial_spectrogram(spectrogram_1_norm, loc_orig_df_1[['seconds_elapsed', 'speed']].values, min_wl, max_wl)
spatial_spectrogram_2_norm = get_spatial_spectrogram(spectrogram_2_norm, loc_orig_df_2[['seconds_elapsed', 'speed']].values, min_wl, max_wl)

# Plots
tlim = (0, tmax)
ax = plot_spectrogram(spatial_spectrogram_1_norm, tlim=tlim, title='Spatial Spectrogram of acc_z dataset 1', spatial=True)
ax_twin = ax.twinx()
ax_twin.plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'], color='blue', label='speed 1')
ax_twin.set_xlim(tlim)
ax_ = plot_spectrogram(spatial_spectrogram_2_norm, tlim=tlim, title='Spatial Spectrogram of acc_z dataset 2', spatial=True)
ax_twin_ = ax_.twinx()
ax_twin_.plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'], color='blue', label='speed 1')
ax_twin_.set_xlim(tlim)
# Out:
# (0.0, 250.0)

# %%
# RMS of acceleration
def rolling_rms(acc_orig_df):
    acc2_cum = np.cumsum(acc_orig_df['z']**2)
    acc_rms = np.zeros(acc_orig_df.shape[0])
    for i in range(acc_orig_df.shape[0]-win_len):
        acc_rms[i+win_len] = np.sqrt((acc2_cum[i+win_len] - acc2_cum[i])/win_len)
    acc_feat_df = pd.DataFrame(data=np.vstack((acc_orig_df['seconds_elapsed'].values, acc_rms)).T, 
                                columns=['seconds_elapsed', 'z_rolling_rms']).fillna(0)
    acc_feat_df.reset_index(inplace=True)
    first_non_zero = np.nonzero(acc_feat_df['z_rolling_rms'].values)[0][0]
    acc_feat_df['z_rolling_rms'].values[:first_non_zero] = acc_feat_df['z_rolling_rms'].values[first_non_zero]
    return acc_feat_df

acc_feat_df_1, acc_feat_df_2 = rolling_rms(acc_orig_df_1), rolling_rms(acc_orig_df_2)

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 5), sharex='all', sharey='row')
ax[0,0].plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'])
ax[1,0].plot(acc_orig_df_1['seconds_elapsed'], acc_orig_df_1['z'])
ax[1,0].plot(acc_feat_df_1['seconds_elapsed'], acc_feat_df_1['z_rolling_rms'])
# ax[1,0].set_xlim([0, 200])
ax[0,1].plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'])
ax[1,1].plot(acc_orig_df_2['seconds_elapsed'], acc_orig_df_2['z'])
ax[1,1].plot(acc_feat_df_2['seconds_elapsed'], acc_feat_df_2['z_rolling_rms'])
# ax[1,1].set_xlim([0, 60])
plt.show()

# %% [markdown]
# ### Low frequency features

# %%
def calc_features_lf_n(loc_orig_df_n, acc_feat_df_n, spectrogram_, spatial_spectrogram_):
    features_lf_n = loc_orig_df_n.loc[:, :]
    features_lf_n['z_rolling_rms'] = \
    np.interp(x=loc_orig_df_n['seconds_elapsed'], 
              xp=acc_feat_df_n['seconds_elapsed'].values-((win_len/fs_acc)/2), fp=acc_feat_df_n['z_rolling_rms'])
    features_lf_n = features_lf_n.drop(columns=['level_0']).reset_index()

    # add spectrogram features (1 column for each frequency bin)
    f, t, Sxx = spectrogram_
    interp_spectrogram = np.array([
        np.interp(x=loc_orig_df_n['seconds_elapsed'], xp=t, fp=Sxx[i])
        for i in range(Sxx.shape[0])
    ])

    spectro_cols = [f'spectrogram_{f[i]}Hz' for i in range(Sxx.shape[0])]
    spectro_df = pd.DataFrame(interp_spectrogram.T, columns=spectro_cols)

    features_lf_n = pd.concat([features_lf_n.reset_index(drop=True), spectro_df], axis=1)

    # add spatial spectrogram (1 column for each spatial frequency bin)
    fs, t, Sxx_spatial = spatial_spectrogram_
    interp_spectrogram_spatial = np.array([
        np.interp(x=loc_orig_df_n['seconds_elapsed'], xp=t, fp=Sxx_spatial[i])
        for i in range(Sxx_spatial.shape[0])
    ])
    spectro_cols_spatial = [f'spatial_spectrogram_{fs[i]}/m' for i in range(Sxx_spatial.shape[0])]
    spectro_df_spatial = pd.DataFrame(interp_spectrogram_spatial.T, columns=spectro_cols_spatial)
    
    features_lf_n = pd.concat([features_lf_n.reset_index(drop=True), spectro_df_spatial], axis=1)

    return features_lf_n


features_lf_1 = calc_features_lf_n(loc_orig_df_1, acc_feat_df_1, spectrogram_1_norm, spatial_spectrogram_1_norm) 
features_lf_2 = calc_features_lf_n(loc_orig_df_2, acc_feat_df_2, spectrogram_2_norm, spatial_spectrogram_2_norm)


# fig, ax = plt.subplots(2, 2, figsize=(20, 10), sharex='all', sharey='row')
# ax[0,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['speed'])
# ax[0,0].set_ylabel('speed (m/s)')
# ax[1,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['z_rolling_rms'])
# ax[1,0].set_ylabel('rms acc. (m/s$^2$)')
# ax[0,1].plot(features_lf_2['seconds_elapsed'], features_lf_2['speed'])
# ax[1,1].plot(features_lf_2['seconds_elapsed'], features_lf_2['z_rolling_rms'])
# ax[1,0].set_xlabel('time (s)')
# ax[1,1].set_xlabel('time (s)')
# plt.show()

# fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex='all', sharey='all')
# ax[0].plot(features_lf_1['z_rolling_rms'], features_lf_1['speed'], linestyle='-', marker='.')
# ax[0].set_xlabel('rms acc. (m/s$^2$)')
# ax[0].set_ylabel('speed (m/s)')
# ax[1].plot(features_lf_2['z_rolling_rms'], features_lf_2['speed'], linestyle='-', marker='.')
# ax[1].set_xlabel('rms acc. (m/s$^2$)')
# plt.show()

# %% [markdown]
# ### Location matching

# %%
def times_matches_1_n(loc_orig_df_1, loc_orig_df_n, features_lf_n):
    # Extract coordinates as arrays
    coords_orig = loc_orig_df_1[['latitude', 'longitude']].values
    coords_dest = loc_orig_df_n[['latitude', 'longitude']].values

    # Compute pairwise distances
    distances = cdist(coords_orig, coords_dest, metric='euclidean')

    # Find the nearest point for each origin point
    nearest_indices = distances.argmin(axis=1)
    nearest_distances = distances.min(axis=1)

    # Build a dictionary of time matches
    time_matches_dict = {}
    for i, (dist, idx) in enumerate(zip(nearest_distances, nearest_indices)):
        orig_time = loc_orig_df_1.iloc[i]['seconds_elapsed']
        dest_time = loc_orig_df_n.iloc[idx]['seconds_elapsed']
        time_matches_dict[orig_time] = dest_time

    # location matching
    loc_orig_df_n_matched = loc_orig_df_1.copy()
    for index, row in loc_orig_df_1.iterrows():
        seconds_elapsed_1 = row['seconds_elapsed']
        if index == len(loc_orig_df_n_matched):
            break
        loc_orig_df_n_matched.iloc[index] = loc_orig_df_n.loc[loc_orig_df_n['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]

    # feature matching
    features_lf_n_matched = features_lf_1.copy()
    for index, row in features_lf_1.iterrows():
        seconds_elapsed_1 = row['seconds_elapsed']
        features_lf_n_matched.iloc[index] = features_lf_n.loc[features_lf_n['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]

    return time_matches_dict, loc_orig_df_n_matched, features_lf_n_matched


time_matches_dict, loc_orig_df_2_matched, features_lf_2_matched = times_matches_1_n(loc_orig_df_1, loc_orig_df_2, features_lf_2)

# %%
fig, ax = plt.subplots(2, 2, figsize=(7, 5), sharey='row', sharex='col')

ax[0,0].plot(loc_orig_df_1['latitude'].values, color='blue', label='pass_1')
ax[0,0].plot(loc_orig_df_2['latitude'].values, color='red', label='pass_2')
ax[1,0].plot(loc_orig_df_1['longitude'].values, color='blue', label='pass_1')
ax[1,0].plot(loc_orig_df_2['longitude'].values, color='red',  label='pass_2')


ax[0,1].plot(loc_orig_df_1['latitude'].values, color='blue', label='pass_1')
ax[0,1].plot(loc_orig_df_2_matched['latitude'].values, color='red',  label='pass_2 matched to pass_1')
ax[1,1].plot(loc_orig_df_1['longitude'].values, color='blue', label='pass_1')
ax[1,1].plot(loc_orig_df_2_matched['longitude'].values, color='red',  label='pass_2 matched to pass_1')

ax[0,0].set_ylabel('latitude (deg.)')
ax[1,0].set_ylabel('longitude (deg.)')
ax[1,0].set_xlabel('actual time (s)')
ax[1,1].set_xlabel('warped time (s)')

for __ in ax:
    for _ in __:
        _.minorticks_on()
        _.legend()

fig.tight_layout()
plt.show()
fig.savefig('location_based_dtw.pdf')

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='col', sharey='row')
ax[0,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['speed'])
ax[0,0].set_ylabel('speed (m/s)')
ax[1,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['z_rolling_rms'])
ax[0,1].plot(features_lf_2_matched['seconds_elapsed'], features_lf_2_matched['speed'])
ax[1,1].plot(features_lf_2_matched['seconds_elapsed'], features_lf_2_matched['z_rolling_rms'])
ax[1,0].set_ylabel('rms acc. (m/s$^2$)')
ax[1,0].set_xlabel('time (s)')
ax[1,1].set_xlabel('time (s)')
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex='all', sharey='all')
ax[0].plot(features_lf_1['z_rolling_rms'], features_lf_1['speed'], linestyle='-', marker='.')
ax[0].set_xlabel('rms acc. (m/s$^2$)')
ax[0].set_ylabel('speed (m/s)')
ax[1].plot(features_lf_2_matched['z_rolling_rms'], features_lf_2_matched['speed'], linestyle='-', marker='.')
ax[1].set_xlabel('rms acc. (m/s$^2$)')
plt.show()

# %% [markdown]
# # Matched spectrograms

# %%
# Matched spectrograms

spectrogram_from_lf_1_ = features_lf_1.loc[:, ['seconds_elapsed'] + [col for col in features_lf_1.columns if ('spectrogram_' in col and 'Hz' in col)]].values
spectrogram_from_lf_1 = (np.linspace(0, fs_acc/2, spectrogram_from_lf_1_.shape[1]-1), spectrogram_from_lf_1_[:,0], spectrogram_from_lf_1_[:, 1:].T)
spectrogram_from_lf_2_ = features_lf_2.loc[:, ['seconds_elapsed'] + [col for col in features_lf_2.columns if ('spectrogram_' in col and 'Hz' in col)]].values
spectrogram_from_lf_2 = (np.linspace(0, fs_acc/2, spectrogram_from_lf_2_.shape[1]-1), spectrogram_from_lf_2_[:,0], spectrogram_from_lf_2_[:, 1:].T)
spectrogram_from_lf_2_matched_ = features_lf_2_matched.loc[:, ['seconds_elapsed'] + [col for col in features_lf_2_matched.columns if ('spectrogram_' in col and 'Hz' in col)]].values
spectrogram_from_lf_2_matched = (np.linspace(0, fs_acc/2, spectrogram_from_lf_2_matched_.shape[1]-1), spectrogram_from_lf_1_[:,0], spectrogram_from_lf_2_matched_[:, 1:].T)

tmax = 250
ax = plot_spectrogram(spectrogram_from_lf_1, tlim=(0, tmax), flim=(0, 25), title='Spectrogram 1', x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(features_lf_1['speed'], color='blue', label='speed 1')
ax_twin.plot(np.mean(spectrogram_from_lf_1[2], axis=0), label='mean spectrum', color='orange')
ax_twin.legend()
ax = plot_spectrogram(spectrogram_from_lf_2_matched, tlim=(0, tmax), flim=(0, 25), title='Spectrogram 2 matched', x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(features_lf_2_matched['speed'], color='blue', label='speed 2')
ax_twin.plot(np.mean(spectrogram_from_lf_2_matched[2], axis=0), label='mean spectrum', color='orange')
ax_twin.legend()
ax = plot_spectrogram(spectrogram_from_lf_2, tlim=(0, tmax), flim=(0, 25), title='Spectrogram 2', x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(features_lf_2['speed'], color='blue', label='speed 1')
ax_twin.plot(np.mean(spectrogram_from_lf_2[2], axis=0), label='mean spectrum', color='orange')
ax_twin.legend()

# %% [markdown]
# ## Velocity normalized spectrograms

# %%
spectrogram_from_lf_1_vel_norm = (
    spectrogram_from_lf_1[0], spectrogram_from_lf_1[1], 
    spectrogram_from_lf_1[2] / features_lf_1['speed'].values.reshape(1, -1)
    )
spectrogram_from_lf_2_matched_vel_norm = (
    spectrogram_from_lf_2_matched[0], spectrogram_from_lf_2_matched[1], 
    spectrogram_from_lf_2_matched[2] / features_lf_2_matched['speed'].values.reshape(1, -1)
    )
spectrogram_from_lf_2_vel_norm = (
    spectrogram_from_lf_2[0], spectrogram_from_lf_2[1], 
    spectrogram_from_lf_2[2] / features_lf_2['speed'].values.reshape(1, -1)
    )

ilim = (-10, 250)
ax = plot_spectrogram(spectrogram_from_lf_1_vel_norm, tlim=ilim, flim=(0, 25), title='Spectrogram 1', x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(features_lf_1['speed'], color='blue', label='speed 1')
ax_twin.plot(np.mean(spectrogram_from_lf_1_vel_norm[2], axis=0), label='mean spectrum', color='orange')
ax_twin.legend()

ax = plot_spectrogram(spectrogram_from_lf_2_matched_vel_norm, tlim=ilim, flim=(0, 25), title='Spectrogram 2 matched', x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(features_lf_2_matched['speed'], color='blue', label='speed 2')
ax_twin.plot(np.mean(spectrogram_from_lf_2_matched_vel_norm[2], axis=0), label='mean spectrum', color='orange')
ax_twin.legend()

ax = plot_spectrogram(spectrogram_from_lf_2_vel_norm, tlim=ilim, flim=(0, 25), title='Spectrogram 2', x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(features_lf_2['speed'], color='blue', label='speed 1')
ax_twin.plot(np.mean(spectrogram_from_lf_2_vel_norm[2], axis=0), label='mean spectrum', color='orange')
ax_twin.legend()

# %% [markdown]
# ## Matched Spatial spectrograms
# $\frac{1}{s} \frac{s}{m}=\frac{1}{m}$

# %%
# Matched spatial spectrograms

spatial_spectrogram_from_lf_1_ = features_lf_1.loc[:, ['seconds_elapsed'] + [col for col in features_lf_1.columns if 'spatial_spectrogram_' in col]].values
spatial_spectrogram_from_lf_1 = (np.linspace(1/max_wl, 1/min_wl, spatial_spectrogram_from_lf_1_.shape[1]-1), spatial_spectrogram_from_lf_1_[:,0], spatial_spectrogram_from_lf_1_[:, 1:].T)
spatial_spectrogram_from_lf_2_ = features_lf_2.loc[:, ['seconds_elapsed'] + [col for col in features_lf_2.columns if 'spatial_spectrogram_' in col]].values
spatial_spectrogram_from_lf_2 = (np.linspace(1/max_wl, 1/min_wl, spatial_spectrogram_from_lf_2_.shape[1]-1), spatial_spectrogram_from_lf_2_[:,0], spatial_spectrogram_from_lf_2_[:, 1:].T)
spatial_spectrogram_from_lf_2_matched_ = features_lf_2_matched.loc[:, ['seconds_elapsed'] + [col for col in features_lf_2_matched.columns if 'spatial_spectrogram_' in col]].values
spatial_spectrogram_from_lf_2_matched = (np.linspace(1/max_wl, 1/min_wl, spatial_spectrogram_from_lf_2_matched_.shape[1]-1), spatial_spectrogram_from_lf_1_[:,0], spatial_spectrogram_from_lf_2_matched_[:, 1:].T)

tlim = (-10, 250)
ax = plot_spectrogram(spatial_spectrogram_from_lf_1, tlim=tlim, flim=(0, 5), title='Spatial Spectrogram 1', spatial=True, x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(loc_orig_df_1['speed'], color='white', label='speed', alpha=0.5)
ax = plot_spectrogram(spatial_spectrogram_from_lf_2_matched, tlim=tlim, flim=(0, 5), title='Spatial Spectrogram 2 matched', spatial=True, x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(loc_orig_df_2_matched['speed'], color='white', label='speed', alpha=0.5)
ax = plot_spectrogram(spatial_spectrogram_from_lf_2, tlim=tlim, flim=(0, 5), title='Spatial Spectrogram 2', spatial=True, x_index=True)
ax_twin = ax.twinx()
ax_twin.plot(loc_orig_df_2['speed'], color='white', label='speed', alpha=0.5)

# %% [markdown]
# # Attention based

# %%
# Normalize spectrograms
def normlize_spectrogram(spectrogram_):
    S = spectrogram_[2]
    global_min, global_max = S.min(), S.max()
    Sxx_norm = (S - global_min) / (global_max - global_min)
    return (spectrogram_[0], spectrogram_[1], Sxx_norm)

spectrogram_from_lf_1 = normlize_spectrogram(spectrogram_from_lf_1)
spectrogram_from_lf_2_matched = normlize_spectrogram(spectrogram_from_lf_2_matched)
spectrogram_from_lf_2 = normlize_spectrogram(spectrogram_from_lf_2)

# %%
import numpy as np


def softmax(x):
    x = x - np.max(x, axis=1, keepdims=True)
    exp_x = np.exp(x)
    return exp_x / np.sum(exp_x, axis=1, keepdims=True)

def self_attention(spectrum_Q, spectrum_K, spectrum_V):
    """    Compute self-attention scores for a given spectrum.
    Args:
        spectrum_Q (np.ndarray): Query spectrum.
        spectrum_K (np.ndarray): Key spectrum.
        spectrum_V (np.ndarray): Value spectrum.
    Returns:
        np.ndarray: Self-attention scores.
    """
    scores = np.dot(spectrum_Q, spectrum_K.T) / np.sqrt(spectrum_Q.shape[1])
    attention_weights = softmax(scores)
    return np.dot(attention_weights, spectrum_V)


def Calc_QKV(spectrogram, W_Q, W_K, W_V):
    """Calculate Query, Key, and Value matrices from the spectrogram.
    Args:
        spectrogram (tuple): The spectrogram data.
        W_Q (np.ndarray): Weight matrix for Query.
        W_K (np.ndarray): Weight matrix for Key.
        W_V (np.ndarray): Weight matrix for Value.
    Returns:
        tuple: Query, Key, and Value matrices.
    """
    f, t, Sxx = spectrogram
    Sxx = Sxx  # Transpose to have time on rows
    Q = np.dot(Sxx, W_Q)
    K = np.dot(Sxx, W_K)
    V = np.dot(Sxx, W_V)
    return Q, K, V

# Assume weight matrices W_Q, W_K, W_V are identity matrices for simplicity
W_Q = np.eye(spectrogram_from_lf_1[2].shape[1])
W_K = np.eye(spectrogram_from_lf_1[2].shape[1])
W_V = np.eye(spectrogram_from_lf_1[2].shape[1]) 

Q_1, K_1, V_1 = Calc_QKV(spectrogram_from_lf_1, W_Q, W_K, W_V)
Q_2, K_2, V_2 = Calc_QKV(spectrogram_from_lf_2_matched, W_Q, W_K, W_V)

att_out_1 = self_attention(Q_1, K_1, V_1).T
att_out_2 = self_attention(Q_2, K_2, V_2).T

flim = (0, 25)
fig, ax = plt.subplots(2, 2, figsize=(10, 7))
plot_spectrogram(spectrogram_from_lf_1, ax=ax[0,0], tlim=(0, 250), flim=flim, title='Spectrogram 1', x_index=True)
plot_spectrogram((spectrogram_from_lf_1[0], spectrogram_from_lf_1[1], att_out_1.T), ax=ax[1,0], 
                 tlim=(0, 250), flim=flim, title='Self-Attention Output for Spectrogram 1', x_index=True)

plot_spectrogram(spectrogram_from_lf_2_matched, ax=ax[0,1], tlim=(0, 250), flim=flim, title='Spectrogram 2 Matched', x_index=True)
plot_spectrogram((spectrogram_from_lf_2_matched[0], spectrogram_from_lf_2_matched[1], att_out_2.T), ax=ax[1,1], 
                 tlim=(0, 250), flim=flim, title='Self-Attention Output for Spectrogram 2 Matched', x_index=True)


fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# plot mean spectra
ax[0].plot(f, np.nanmean(spectrogram_from_lf_1[2], axis=1), color='blue', label='Mean Spectrum 1', alpha=0.25)
ax0t = ax[0].twinx()
ax0t.plot(f, np.nanmean(att_out_1.T, axis=1), color='red', label='Self-Attention Output per Mean Spectrum 1', alpha=0.25)
ax[1].plot(f, np.nanmean(spectrogram_from_lf_2_matched[2], axis=1), color='blue', label='Mean Spectrum 2 Matched', alpha=0.25)
ax1t = ax[1].twinx()
ax1t.plot(f, np.nanmean(att_out_2.T, axis=1), color='red', label='Self-Attention Output per Mean Spectrum 2 Matched', alpha=0.25)


# Apply a simple moving average smoothing with window size 5
smooth = lambda x, w=11: np.convolve(x, np.ones(w)/w, mode='same')

# plot mean spectra for spectrogram_from_lf_1
mean_spec1 = np.nanmean(spectrogram_from_lf_1[2], axis=1)
mean_att1 = np.nanmean(att_out_1.T, axis=1)
ax[0].plot(f, smooth(mean_spec1), color='blue', label='Smoothed Mean Spectrum 1')
ax[0].set_xlim(flim)
ax0t.plot(f, smooth(mean_att1), color='red', label='Smoothed Self-Attention Output per Mean Spectrum 1')

# plot mean spectra for spectrogram_from_lf_2_matched
mean_spec2 = np.nanmean(spectrogram_from_lf_2_matched[2], axis=1)
mean_att2 = np.nanmean(att_out_2.T, axis=1)
ax[1].plot(f, smooth(mean_spec2), color='blue', label='Smoothed Mean Spectrum 2 Matched')
ax[1].set_xlim(flim)
ax1t.plot(f, smooth(mean_att2), color='red', label='Smoothed Self-Attention Output per Mean Spectrum 2 Matched')

# %%
f, t, Sxx = spectrogram_from_lf_1
f.shape, t.shape, Sxx.shape, att_out_1.shape
# Out:
# ((251,), (225,), (251, 225), (225, 251))

# %% [markdown]
# ## Learneable weights

# %%
# Self-Attention Denoising Autoencoder for Spectrograms (trainable W_Q, W_K, W_V)
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model


# --------------------------
# Utilities
# --------------------------
def masked_mse(y_true, y_pred):
    # Separamos clean y mask del y_true empaquetado
    clean = y_true[..., :-1]       # espectrograma limpio
    mask  = y_true[..., -1:]       # última "frecuencia" = máscara
    se = tf.square(clean - y_pred) * mask
    denom = tf.reduce_sum(mask) + 1e-8
    return tf.reduce_sum(se) / denom

def pad_to_length(x, target_len, pad_value=0.0):
    """Pad a [T, F] array to [target_len, F]."""
    T, F = x.shape
    if T == target_len:
        return x
    out = np.full((target_len, F), pad_value, dtype=x.dtype)
    out[:T] = x
    return out

def build_dataset_from_spectrograms(spectrogram_list, T_max=None, add_noise=True, noise_std=0.1):
    """
    spectrogram_list: list of (f, t, Sxx) with Sxx shaped [T, F], time along rows.
    Returns: dataset of (noisy_input, clean_target, mask) with shapes:
             X: [N, T_pad, F], Y: [N, T_pad, F], mask: [N, T_pad] (1 for real, 0 for pad)
    """
        
    Sxx_list = [np.asarray(s[2]) for s in spectrogram_list]  # [T, F]
    F = Sxx_list[0].shape[1]
    if T_max is None:
        T_max = max(S.shape[0] for S in Sxx_list)

    X_clean = []
    mask = []
    for S in Sxx_list:
        T = S.shape[0]
        X_clean.append(pad_to_length(S, T_max, pad_value=0.0))
        m = np.zeros((T_max,), dtype=np.float32); m[:T] = 1.0
        mask.append(m)

    X_clean = np.stack(X_clean, axis=0).astype(np.float32)  # [N, T_max, F]
    mask = np.stack(mask, axis=0).astype(np.float32)        # [N, T_max]

    if add_noise:
        noise = np.random.normal(0.0, noise_std, size=X_clean.shape).astype(np.float32)
        X_noisy = X_clean + noise
    else:
        X_noisy = X_clean

    # Replace NaNs (if any) with zeros; keep a separate valid mask (already provided)
    X_noisy = np.nan_to_num(X_noisy, nan=0.0, posinf=0.0, neginf=0.0)
    X_clean = np.nan_to_num(X_clean, nan=0.0, posinf=0.0, neginf=0.0)
        
    return (X_noisy, X_clean, mask), F, T_max


# --------------------------
# Model: Denoising Autoencoder with Self-Attention
# --------------------------
def build_sae_model(F, d_k=64, hidden_decoder=128, transpose=False):
    X_in = layers.Input(shape=(None, F), name="X_in")

    # Encoder (con learnable Q, K, V)
    Q = layers.Dense(d_k)(X_in)
    K = layers.Dense(d_k)(X_in)
    V = layers.Dense(d_k)(X_in)

    attn_scores = layers.Lambda(lambda x: tf.matmul(x[0], x[1], transpose_b=True) / tf.sqrt(float(d_k)))([Q, K])
    attn_weights = layers.Softmax(axis=-1)(attn_scores)
    attn_out = layers.Lambda(lambda x: tf.matmul(x[0], x[1]))([attn_weights, V])

    encoded = layers.Dense(hidden_decoder, activation="linear")(attn_out)

    # Decoder
    decoded = layers.Dense(F, activation="linear")(encoded)

    return Model(X_in, decoded)

# %%
min(spectrogram_from_lf_1[2].flatten()), max(spectrogram_from_lf_1[2].flatten())
# Out:
# (0.0, 1.0)

# %%
# --------------------------
# Example: preparing data and training
# --------------------------
# Suppose you have: spectrogram_from_lf_1, spectrogram_from_lf_2_matched, ...
# Build a list like:
# your_spectrogram_list = [spectrogram_from_lf_1, spectrogram_from_lf_2_matched, ...]
# Each item is (f, t, Sxx) with Sxx shaped [T, F] (time on rows).

# (Uncomment and adapt)
(X_noisy, X_clean, mask), F, T_max = build_dataset_from_spectrograms(
    [spectrogram_from_lf_1], T_max=None, add_noise=True, noise_std=0.1
)

F = X_noisy.shape[-1]
model = build_sae_model(F, d_k=10, hidden_decoder=1)
model.summary()

Y = np.concatenate([X_clean, mask[..., None]], axis=-1)

model.compile(optimizer="adam", loss=masked_mse)
model.fit(X_noisy, Y, batch_size=10, epochs=300, shuffle=True)
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_in (InputLayer)           [(None, None, 225)]          0         []
#
#  dense_100 (Dense)           (None, None, 10)             2260      ['X_in[0][0]']
#
#  dense_101 (Dense)           (None, None, 10)             2260      ['X_in[0][0]']
#
#  lambda_40 (Lambda)          (None, None, None)           0         ['dense_100[0][0]',
#                                                                      'dense_101[0][0]']
#
#  softmax_20 (Softmax)        (None, None, None)           0         ['lambda_40[0][0]']
#
#  dense_102 (Dense)           (None, None, 10)             2260      ['X_in[0][0]']
#
#  lambda_41 (Lambda)          (None, None, 10)             0         ['softmax_20[0][0]',
#                                                                      'dense_102[0][0]']
#
#  dense_103 (Dense)           (None, None, 1)              11        ['lambda_41[0][0]']
#
#  dense_104 (Dense)           (None, None, 225)            450       ['dense_103[0][0]']
#
# ==================================================================================================
# Total params: 7241 (28.29 KB)
# Trainable params: 7241 (28.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.3196
# Epoch 2/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3134
# Epoch 3/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3088
# Epoch 4/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3048
# Epoch 5/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3008
# Epoch 6/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2970
# Epoch 7/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2937
# Epoch 8/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2909
# Epoch 9/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2884
# Epoch 10/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2862
# Epoch 11/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2841
# Epoch 12/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2822
# Epoch 13/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2805
# Epoch 14/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2791
# Epoch 15/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2778
# Epoch 16/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2767
# Epoch 17/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2757
# Epoch 18/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2748
# Epoch 19/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2740
# Epoch 20/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2733
# Epoch 21/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2727
# Epoch 22/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2722
# Epoch 23/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2717
# Epoch 24/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2712
# Epoch 25/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2708
# Epoch 26/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2704
# Epoch 27/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2700
# Epoch 28/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2697
# Epoch 29/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2694
# Epoch 30/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2692
# Epoch 31/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2689
# Epoch 32/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2686
# Epoch 33/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2684
# Epoch 34/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2682
# Epoch 35/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2681
# Epoch 36/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2679
# Epoch 37/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2677
# Epoch 38/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2675
# Epoch 39/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2674
# Epoch 40/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2673
# Epoch 41/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2671
# Epoch 42/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2670
# Epoch 43/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2669
# Epoch 44/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2668
# Epoch 45/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2667
# Epoch 46/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2665
# Epoch 47/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2664
# Epoch 48/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2663
# Epoch 49/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2662
# Epoch 50/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2661
# Epoch 51/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2660
# Epoch 52/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2659
# Epoch 53/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2658
# Epoch 54/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2656
# Epoch 55/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2655
# Epoch 56/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2654
# Epoch 57/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2652
# Epoch 58/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2651
# Epoch 59/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2649
# Epoch 60/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2647
# Epoch 61/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2646
# Epoch 62/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2644
# Epoch 63/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2641
# Epoch 64/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2639
# Epoch 65/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2636
# Epoch 66/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2634
# Epoch 67/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2631
# Epoch 68/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2627
# Epoch 69/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2624
# Epoch 70/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2620
# Epoch 71/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2616
# Epoch 72/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2612
# Epoch 73/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2607
# Epoch 74/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2602
# Epoch 75/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2596
# Epoch 76/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2591
# Epoch 77/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2585
# Epoch 78/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2578
# Epoch 79/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2571
# Epoch 80/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2564
# Epoch 81/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2557
# Epoch 82/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2549
# Epoch 83/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2540
# Epoch 84/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2531
# Epoch 85/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2522
# Epoch 86/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2512
# Epoch 87/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2502
# Epoch 88/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2491
# Epoch 89/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2480
# Epoch 90/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2469
# Epoch 91/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2458
# Epoch 92/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2446
# Epoch 93/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2433
# Epoch 94/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2421
# Epoch 95/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2408
# Epoch 96/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2395
# Epoch 97/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2381
# Epoch 98/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2368
# Epoch 99/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2354
# Epoch 100/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2340
# Epoch 101/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2326
# Epoch 102/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2311
# Epoch 103/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2297
# Epoch 104/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2283
# Epoch 105/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2268
# Epoch 106/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2254
# Epoch 107/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2240
# Epoch 108/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2225
# Epoch 109/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2211
# Epoch 110/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2197
# Epoch 111/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2183
# Epoch 112/300
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2169
# Epoch 113/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2156
# Epoch 114/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2142
# Epoch 115/300
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2129
# Epoch 116/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2116
# Epoch 117/300
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2103
# Epoch 118/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2091
# Epoch 119/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2079
# Epoch 120/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2067
# Epoch 121/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2056
# Epoch 122/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2045
# Epoch 123/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2034
# Epoch 124/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2024
# Epoch 125/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2013
# Epoch 126/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2004
# Epoch 127/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1994
# Epoch 128/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1985
# Epoch 129/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1976
# Epoch 130/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1967
# Epoch 131/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1959
# Epoch 132/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1951
# Epoch 133/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1943
# Epoch 134/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1936
# Epoch 135/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1928
# Epoch 136/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1921
# Epoch 137/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1914
# Epoch 138/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1908
# Epoch 139/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1901
# Epoch 140/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1895
# Epoch 141/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1889
# Epoch 142/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1884
# Epoch 143/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1878
# Epoch 144/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1873
# Epoch 145/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1867
# Epoch 146/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1862
# Epoch 147/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1858
# Epoch 148/300
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1853
# Epoch 149/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1849
# Epoch 150/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1844
# Epoch 151/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1840
# Epoch 152/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1836
# Epoch 153/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1832
# Epoch 154/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1828
# Epoch 155/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1825
# Epoch 156/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1821
# Epoch 157/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1818
# Epoch 158/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1815
# Epoch 159/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1812
# Epoch 160/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1809
# Epoch 161/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1806
# Epoch 162/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1803
# Epoch 163/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1801
# Epoch 164/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1798
# Epoch 165/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1796
# Epoch 166/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1793
# Epoch 167/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1791
# Epoch 168/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1789
# Epoch 169/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1787
# Epoch 170/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1785
# Epoch 171/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1783
# Epoch 172/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1781
# Epoch 173/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1779
# Epoch 174/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1777
# Epoch 175/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1776
# Epoch 176/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1774
# Epoch 177/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1772
# Epoch 178/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1771
# Epoch 179/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1769
# Epoch 180/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1768
# Epoch 181/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1766
# Epoch 182/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1765
# Epoch 183/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1764
# Epoch 184/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1763
# Epoch 185/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1761
# Epoch 186/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1760
# Epoch 187/300
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1759
# Epoch 188/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1758
# Epoch 189/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1757
# Epoch 190/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1756
# Epoch 191/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1755
# Epoch 192/300
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1754
# Epoch 193/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1753
# Epoch 194/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1752
# Epoch 195/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1751
# Epoch 196/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1750
# Epoch 197/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1749
# Epoch 198/300
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1748
# Epoch 199/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1748
# Epoch 200/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1747
# Epoch 201/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1746
# Epoch 202/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1745
# Epoch 203/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1744
# Epoch 204/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1744
# Epoch 205/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1743
# Epoch 206/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1742
# Epoch 207/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1742
# Epoch 208/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1741
# Epoch 209/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1740
# Epoch 210/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1740
# Epoch 211/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1739
# Epoch 212/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1738
# Epoch 213/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1738
# Epoch 214/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1737
# Epoch 215/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1737
# Epoch 216/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1736
# Epoch 217/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1736
# Epoch 218/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1735
# Epoch 219/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1735
# Epoch 220/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1734
# Epoch 221/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1734
# Epoch 222/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1733
# Epoch 223/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1733
# Epoch 224/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1732
# Epoch 225/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1732
# Epoch 226/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1731
# Epoch 227/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1731
# Epoch 228/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1730
# Epoch 229/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1730
# Epoch 230/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1730
# Epoch 231/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1729
# Epoch 232/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1729
# Epoch 233/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1728
# Epoch 234/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1728
# Epoch 235/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1728
# Epoch 236/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1727
# Epoch 237/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1727
# Epoch 238/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1727
# Epoch 239/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1726
# Epoch 240/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1726
# Epoch 241/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1726
# Epoch 242/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1725
# Epoch 243/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1725
# Epoch 244/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1725
# Epoch 245/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1724
# Epoch 246/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1724
# Epoch 247/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1724
# Epoch 248/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1724
# Epoch 249/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1723
# Epoch 250/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1723
# Epoch 251/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1723
# Epoch 252/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1723
# Epoch 253/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1722
# Epoch 254/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1722
# Epoch 255/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1722
# Epoch 256/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1722
# Epoch 257/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1721
# Epoch 258/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1721
# Epoch 259/300
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1721
# Epoch 260/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1721
# Epoch 261/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1721
# Epoch 262/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1720
# Epoch 263/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1720
# Epoch 264/300
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1720
# Epoch 265/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1720
# Epoch 266/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1720
# Epoch 267/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1720
# Epoch 268/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1719
# Epoch 269/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1719
# Epoch 270/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1719
# Epoch 271/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1719
# Epoch 272/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1719
# Epoch 273/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1719
# Epoch 274/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1719
# Epoch 275/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1718
# Epoch 276/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1718
# Epoch 277/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1718
# Epoch 278/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1718
# Epoch 279/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1718
# Epoch 280/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1718
# Epoch 281/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1718
# Epoch 282/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1717
# Epoch 283/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1717
# Epoch 284/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1717
# Epoch 285/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1717
# Epoch 286/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1717
# Epoch 287/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1717
# Epoch 288/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1717
# Epoch 289/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1717
# Epoch 290/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1717
# Epoch 291/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1717
# Epoch 292/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1716
# Epoch 293/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1716
# Epoch 294/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1716
# Epoch 295/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1716
# Epoch 296/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1716
# Epoch 297/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1716
# Epoch 298/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1716
# Epoch 299/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1716
# Epoch 300/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1716

# %%
# plot training loss
plt.plot(model.history.history['loss'])

# %%
plt.figure(figsize=(10, 5))
plot_spectrogram((spectrogram_from_lf_1[0], spectrogram_from_lf_1[1], spectrogram_from_lf_1[2]), tlim=(0, 250), flim=(0, 25), title='Denoised Spectrogram 1', x_index=True)
# plt.ylim(0, 5)

plt.figure(figsize=(10, 5))
plot_spectrogram((spectrogram_from_lf_1[0], 
                  spectrogram_from_lf_1[1], 
                  np.diff(spectrogram_from_lf_1[2], 1, axis=1, append=0)), 
                  tlim=(0, 250), flim=(0, 25), title='Denoised Spectrogram 1', x_index=True)
# plt.ylim(0, 5)
# Out:
# <Axes: title={'center': 'Denoised Spectrogram 1'}, xlabel='Sample index', ylabel='Frequency [Hz]'>
